# %%
from google.colab import drive
drive.mount('/content/gdrive')

import numpy as np
import tensorflow as tf
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# #### TensorFlow로 간단한 Linear Regression 구현

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-5d12d9124b95> in <module>()
#       4 W = tf.Variable(tf.random.normal([1]), name='weight')
#       5 b = tf.Variable(tf.random.normal([1]), name='bias')
# ----> 6 X = tf.placeholder(tf.float32, shape=[None])
#       7 Y = tf.placeholder(tf.float32, shape=[None])
#       8
#
# AttributeError: module 'tensorflow' has no attribute 'placeholder'

# %% [markdown]
# #### Linear Regression의 Cost 최소화

# %%
# Out:
# '2.4.1'
